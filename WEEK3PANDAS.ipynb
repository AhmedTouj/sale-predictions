# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedTouj/sale-predictions/blob/main/WEEK3PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as df

# %%
filep='/content/drive/MyDrive/datasets/Mod_employee_attrition - Temp employee_attrition.csv'

# %%
table=df.read_csv(filep)

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1475 entries, 0 to 1474
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1475 non-null   int64
#  1   Attrition                 1475 non-null   object
#  2   BusinessTravel            1475 non-null   object
#  3   Department                1475 non-null   object
#  4   DistanceFromHome          1475 non-null   int64
#  5   Education                 1475 non-null   int64
#  6   EducationField            1475 non-null   object
#  7   EmployeeCount             1475 non-null   int64
#  8   EmployeeNumber            1475 non-null   int64
#  9   EnvironmentSatisfaction   1475 non-null   int64
#  10  Gender                    590 non-null    object
#  11  HourlyRate                1475 non-null   object
#  12  JobInvolvement            1475 non-null   int64
#  13  JobLevel                  1475 non-null   int64
# ...

# %%
table.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction StandardHours  \
# ...

# %%
table.head(3)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction StandardHours  \
# 0                        2  ...                        1            80
# 1                        3  ...                        4            80
# 2                        4  ...                        2            80
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# ...

# %%
table.tail(3)
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1472   27        No      Travel_Rarely  Research & Development
# 1473   49        No  Travel_Frequently                   Sales
# 1474   34        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1472                 4          3  Life Sciences              1
# 1473                 2          3        Medical              1
# 1474                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction  ... RelationshipSatisfaction  \
# 1472            2064                        2  ...                        2
# 1473            2065                        4  ...                        4
# 1474            2068                        2  ...                        1
#
#      StandardHours  StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# ...

# %%
table.sample(3)
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 1235   24        No  Travel_Rarely  Research & Development                29
# 388    37        No  Travel_Rarely  Research & Development                14
# 1139   46        No  Travel_Rarely                   Sales                 1
#
#       Education EducationField  EmployeeCount  EmployeeNumber  \
# 1235          1        Medical              1            1725
# 388           3  Life Sciences              1             515
# 1139          4  Life Sciences              1            1602
#
#       EnvironmentSatisfaction  ... RelationshipSatisfaction StandardHours  \
# 1235                        2  ...                        2            80
# 388                         4  ...                        3            80
# 1139                        4  ...                        2            80
#
#       StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# ...

# %%
table['Age'].dtype
# Out:
# dtype('int64')

# %%
table.shape
# Out:
# (1475, 35)

# %%
len(table)
# Out:
# 1475

# %%
dfAge=table['Age']
dfAge
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1470    36
# 1471    39
# 1472    27
# 1473    49
# 1474    34
# Name: Age, Length: 1475, dtype: int64

# %%
df3=table[['Age','Attrition','Department']]
df3
# Out:
#       Age Attrition              Department
# 0      41       Yes                   Sales
# 1      49        No  Research & Development
# 2      37       Yes  Research & Development
# 3      33        No  Research & Development
# 4      27        No  Research & Development
# ...   ...       ...                     ...
# 1470   36        No  Research & Development
# 1471   39        No  Research & Development
# 1472   27        No  Research & Development
# 1473   49        No                   Sales
# 1474   34        No  Research & Development
#
# [1475 rows x 3 columns]

# %%
file_url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vSBBVejdY87e_8cMG9xUEu2Q2DiQC1rHBgmq9ecR8kduFcdsae_Z1B12303buUISaPhHWopT9-Howzi/pub?output=csv#"
tab2 = df.read_csv(file_url, index_col=1)
display(tab2.head())
tab2.index
# Out:
#         EmployeeID  Height  Age State            Role
# Name
# Tom              1      68   33    CA  Senior Advisor
# Jerry            2      72   27    NY  Junior Advisor
# Ann              3      69   42    MD    Senior Agent
# Hubert           4      68   35    WA    Junior Agent
# Monica           5      63   64    TX    Senior Agent
# Index(['Tom', 'Jerry', 'Ann', 'Hubert', 'Monica', 'Suzy', 'Greg', 'Bob',
#        'Nora', 'Vadim', 'John'],
#       dtype='object', name='Name')

# %%
tab2.index
# Out:
# Index(['Tom', 'Jerry', 'Ann', 'Hubert', 'Monica', 'Suzy', 'Greg', 'Bob',
#        'Nora', 'Vadim', 'John'],
#       dtype='object', name='Name')
